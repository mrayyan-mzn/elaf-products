# %%
import pandas as pd

# %%
df = pd.read_json("./elaf_categories_with_sequential.json")
df['id'] = df['id'].replace('-', '_',  regex=True).str.upper()
with open('elaf_categories.json', 'w', encoding='utf-8') as f:
    df.to_json(f, force_ascii=False, orient='records', indent=4)
